# %% [markdown]
# <a href="https://colab.research.google.com/github/choius0528/Machine-Learning_Study/blob/main/11%EC%A3%BC%EC%B0%A8/AE_w11_credit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Auto Encoder - 신용카드 데이터
# Autoencoder-Credit Card Fraud Detection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
#데이터 불러오기
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/creditcard.csv')

df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
LABELS = ["Normal", "Fraud"]

count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# /tmp/ipython-input-2226809669.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['Class'], sort = True)

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.244964
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.342475
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.160686
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.140534
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153 -0.073403
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731 -0.350151
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527 -0.254117
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561 -0.081839
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533 -0.313249
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  0.514355
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 30 columns]

# %%
RANDOM_SEED = 42

# %%
#train & test 나누기
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train.shape
# Out:
# (227451, 29)

# %%
#오토 인코더 모델
input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
#오토 인코더 모델 학습
history = autoencoder.fit(X_train, X_train,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.1131 - val_loss: 0.9054
# Epoch 2/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.9043 - val_loss: 0.8781
# Epoch 3/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9058 - val_loss: 0.8576
# Epoch 4/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8799 - val_loss: 0.8494
# Epoch 5/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8749 - val_loss: 0.8430
# Epoch 6/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8620 - val_loss: 0.8371
# Epoch 7/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8468 - val_loss: 0.8345
# Epoch 8/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8462 - val_loss: 0.8328
# Epoch 9/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8702 - val_loss: 0.8304
# Epoch 10/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8525 - val_loss: 0.8290
# Epoch 11/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8298 - val_loss: 0.8280
# Epoch 12/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8648 - val_loss: 0.8271
# Epoch 13/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8422 - val_loss: 0.8253
# Epoch 14/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8282 - val_loss: 0.8243
# Epoch 15/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8216 - val_loss: 0.8238
# Epoch 16/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8448 - val_loss: 0.8232
# Epoch 17/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8385 - val_loss: 0.8229
# Epoch 18/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8315 - val_loss: 0.8227
# Epoch 19/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8420 - val_loss: 0.8222
# Epoch 20/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8398 - val_loss: 0.8221
# Epoch 21/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8334 - val_loss: 0.8221
# Epoch 22/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8290 - val_loss: 0.8217
# Epoch 23/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8317 - val_loss: 0.8220
# Epoch 24/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8526 - val_loss: 0.8215
# Epoch 25/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8187 - val_loss: 0.8216
# Epoch 26/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8355 - val_loss: 0.8216
# Epoch 27/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8369 - val_loss: 0.8214
# Epoch 28/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8347 - val_loss: 0.8212
# Epoch 29/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8526 - val_loss: 0.8210
# Epoch 30/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8376 - val_loss: 0.8208
# Epoch 31/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8427 - val_loss: 0.8207
# Epoch 32/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8452 - val_loss: 0.8206
# Epoch 33/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8193 - val_loss: 0.8205
# Epoch 34/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8312 - val_loss: 0.8206
# Epoch 35/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8575 - val_loss: 0.8204
# Epoch 36/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8100 - val_loss: 0.8204
# Epoch 37/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8340 - val_loss: 0.8201
# Epoch 38/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8494 - val_loss: 0.8200
# Epoch 39/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8451 - val_loss: 0.8200
# Epoch 40/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8364 - val_loss: 0.8199
# Epoch 41/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8371 - val_loss: 0.8182
# Epoch 42/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8615 - val_loss: 0.8161
# Epoch 43/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8303 - val_loss: 0.8156
# Epoch 44/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8605 - val_loss: 0.8155
# Epoch 45/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8805 - val_loss: 0.8153
# Epoch 46/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8232 - val_loss: 0.8151
# Epoch 47/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8324 - val_loss: 0.8150
# Epoch 48/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8430 - val_loss: 0.8148
# Epoch 49/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8146 - val_loss: 0.8147
# Epoch 50/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8413 - val_loss: 0.8144

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.856723      0.001720
# std                3.712680      0.041443
# min                0.054649      0.000000
# 25%                0.266737      0.000000
# 50%                0.447441      0.000000
# 75%                0.713058      0.000000
# max              259.737099      1.000000

# %%
error_df.head()
# Out:
#         reconstruction_error  true_class
# 43428              81.923737           1
# 49906               0.944636           0
# 29474               0.356950           0
# 276481              0.369457           0
# 278846              0.196916           0

# %%
threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.14      0.37      0.20        98
#
#     accuracy                           1.00     56962
#    macro avg       0.57      0.68      0.60     56962
# weighted avg       1.00      1.00      1.00     56962
